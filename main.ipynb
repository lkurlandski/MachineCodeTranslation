# %%
from pathlib import Path

import capstone
from capstone import *
import numpy as np

# %%
CODE = b"\x55\x48\x8b\x05\xb8\x13\x00\x00"

md = Cs(CS_ARCH_X86, CS_MODE_64)
for i in md.disasm(CODE, 0x1000):
    print("0x%x:\t%s\t%s" %(i.address, i.mnemonic, i.op_str))
# Out:
# 0x1000:	push	rbp
# 0x1001:	mov	rax, qword ptr [rip + 0x13b8]

# %%
data_path = Path("/home/lk3591/Documents/datasets/MachineCodeTranslation/KernelShap/softmaxFalse/256/50/1/attributions")
mal_path = data_path / "malicious" / "0"
ben_path = data_path / "benign" / "0"

# %%
def read_binary(file: Path, mode: str = "rb"):
    with open(file, mode) as f:
        x = np.frombuffer(f.read(), dtype=np.uint8).astype(np.int16) + 1
    return x

def CsInsn_str(i):

# %%
file = mal_path / "3d2a29444b36f7fe55015d8227622d9cafb7ee51e20d52e8f53cad68.exe_914688_914944.bin"
with open(file, "rb") as f:
    binary = f.read()

# %%
md = Cs(CS_ARCH_X86, CS_MODE_64)
dis = [i for i in md.disasm_lite(binary, 0x0000)]

# %%
for i in md.disasm_lite(binary, 0x0000):
    print(f"{i[2]} {i[3]}")
# Out:
# or al, 0xc8
# mov eax, dword ptr [r8]
# mov dword ptr [rcx + 0x3c], eax
# cmp dword ptr [rip + 0x8075e1], r12d
# je 0x1a
# lea r8, [rip + 0x8075d8]
# jmp 0x66
# cmp dword ptr [rip + 0x8075cb], r12d
# je 0x30
# movzx edx, r10w
# lea r8, [rip + 0x8075be]
# jmp 0x66
# cmp dword ptr [rip + 0x8075b1], r12d
# je 0x46
# movzx edx, r11w
# lea r8, [rip + 0x8075a4]
# jmp 0x66
# cmp dword ptr [rip + 0x807597], r12d
# je 0x5b
# movzx edx, bp
# lea r8, [rip + 0x80758b]
# jmp 0x66
# movzx edx, r12w
# lea r8, [rip + 0x80757a]
# mov rax, qword ptr [rip + 0x7fe4cb]
# mov word ptr [rax + r9*8 + 0x32], dx
# mov rax, qword ptr [rip + 0x7fe4be]
# lea rcx, [rax + r9*8]
# mov eax, dword ptr [r8]
# mov dword ptr [rcx + 0x2c], eax
# call 0xfffffffffff212c0
# movsxd rax, dword ptr [rip + 0x80759c]
# lea rcx, [rax + rax*2]
# mov rax, qword ptr [rip + 0x807595]
# add rcx, rcx
# movsxd rdx, dword ptr [rax + rcx*8 + 8]
# mov rax, qword ptr [rip + 0x7fe48e]
# mov dword ptr [rax + rdx*8 + 4], r15d
# ...

# %%
md32 = Cs(CS_ARCH_X86, CS_MODE_32)
dis32 = [i for i in md.disasm_lite(binary, 0x0000)]

# %%
# Out:
#   Input In [28]
#     dis32 === dis
#             ^
# SyntaxError: invalid syntax

# %%
from collections import Counter
from main import mal_path, ben_path
from main import disassemble_snippet_file

# %%
s1 = 0
mal_failures = Counter()
for f in mal_path.iterdir():
    try:
        disassemble_snippet_file(f)
        s1 += 1
    except ValueError as e:
        file = str(e).split(":")[1][1:].split("_")[0]
        mal_failures.update([file])
s1
# Out:
# 1178061

# %%
mal_failures.most_common()
# Out:
# [('00058d9255f48d46f769c35e69450d11381300f4c1edf68323c6997fb7e26428', 225),
#  ('001ab352a59410f7370245774a9a4bd5ff54da8ecefe3243e8b2c8dfe7a0d40c', 202),
#  ('00267ffa7dcac9fef3e2adafd660af2f408a93feb7bcd19ce5e48d60c96d589a', 174),
#  ('0004ec2aed3a88c14f9fa66a651e97ddc6829b26110c749e54433be5b22a6b74', 172),
#  ('0029b660028f2ce6c24753640b935a2a226759087420003fc83f23bc582cd208', 153),
#  ('002508273607f642dace031721bf5629cbbab3c996d7eacff0b1745173fb5ee0', 145),
#  ('0012983a83a526c6fe14e5ea86e1bc7f060683311775c392c9e084882a7ecbaf', 136),
#  ('0026fc07247e96fce23446096ed629259eafe9fb7be083004198967c8c0f9042', 119),
#  ('33c840548d50fb132fbf76c83fcf4e5e14ea3af95cb251fa2e09dd36.exe', 113),
#  ('001797554f1e63776bd4d138b5b2274109dda6e3973b7758e239cda9a417e2a0', 103),
#  ('00104126f0d05320de9ede81e9cf8ec0a1909c85ed65d849a066fcd7384cf208', 102),
#  ('000d731f6456189d12b27dbe41b5ef6968e1cc66a42e0cca09f9ce7d602c78cb', 102),
# ...

# %%
s2 = 0
ben_failures = Counter()
for f in ben_path.iterdir():
    try:
        disassemble_snippet_file(f)
        s2 += 1
    except ValueError as e:
        file = str(e).split(":")[1][1:].split("_")[0]
        ben_failures.update([file])
s2
# Out:
# 1503977

# %%
def move_non_parseable_malware
# Out:
# 1178061
